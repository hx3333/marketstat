# %%
import yfinance as yf
import mplfinance as mpf
import matplotlib.pyplot as plt
# %matplotlib inline

ticker = 'AAPL'
start = '2021-05-17'
interval = '1d'

data = yf.download(tickers=ticker, period='1y',interval=interval)
print(data)

col = mpf.make_marketcolors(up='#ff8500', down='#1b90a7', inherit=True)
sty = mpf.make_mpf_style(base_mpf_style='nightclouds',marketcolors=col)

data['vmap'] = (((data['High']+data['Low'])/2)*data['Volume']).cumsum() / data['Volume'].cumsum()
add = mpf.make_addplot(data['vmap'])
kwargs = dict(type='candle', volume=True, style=sty, mav=(6,12), addplot=add)

mpf.plot(data, **kwargs)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-05-18   78.292503   79.125000   77.580002   78.739998   78.212997
# 2020-05-19   78.757500   79.629997   78.252502   78.285004   77.761040
# 2020-05-20   79.169998   79.879997   79.129997   79.807503   79.273354
# 2020-05-21   79.665001   80.222504   78.967499   79.212502   78.682327
# 2020-05-22   78.942497   79.807503   78.837502   79.722504   79.188927
# ...                ...         ...         ...         ...         ...
# 2021-05-11  123.500000  126.269997  122.769997  125.910004  125.910004
# 2021-05-12  123.400002  124.639999  122.250000  122.769997  122.769997
# 2021-05-13  124.580002  126.150002  124.260002  124.970001  124.970001
# 2021-05-14  126.250000  127.889999  125.849998  127.449997  127.449997
# 2021-05-17  126.820000  126.930000  125.169998  126.269997  126.269997
#
#                Volume
# Date
# 2020-05-18  135178400
# 2020-05-19  101729600
# 2020-05-20  111504800
# 2020-05-21  102688800
# 2020-05-22   81803200
# ...               ...
# 2021-05-11  126142800
# 2021-05-12  112172300
# 2021-05-13  105861300
# 2021-05-14   81806500
# 2021-05-17   74163100
#
# [252 rows x 6 columns]
